# %% [markdown]
# # Python Advanced Assignment_21

# %% [markdown]
# ### Q1. What is a probability distribution, exactly? If the values are meant to be random, how can you predict them at all?

# %% [markdown]
# ##### ANSWER:

# %% [markdown]
# A __probability distribution__ describes how a random variable is distributed.
#
# It tells us which values a random variable is most likely to take on and which values are less likely. Based on the previous data and the occurences of the random event, we can predict the outcome in terms of probabilities.

# %% [markdown]
# ### Q2. Is there a distinction between true random numbers and pseudo-random numbers, if there is one? Why are the latter considered “good enough”?

# %% [markdown]
# ##### ANSWER:

# %% [markdown]
# __True Random Numbers__ are true physical values whereas __pseudo-random numbers__ are generated internally by a program. The latter is considered good enough as they have sort of uniform distribution.

# %% [markdown]
# ### Q3. What are the two main factors that influence the behaviour of a "normal" probability distribution?

# %% [markdown]
# ##### ANSWER:

# %% [markdown]
# The two main factors that influence the behaviour of a "normal" probability distribution are :
#
#
# - __Mean__
#
#
# - __Variance__

# %% [markdown]
# ### Q4. Provide a real-life example of a normal distribution.

# %% [markdown]
# ##### ANSWER:

# %% [markdown]
# A real-life example of a normal distribution is __Rolling A Dice__ .
#
# A fair _rolling of dice_ is also a good example of normal distribution. In an experiment, it has been found that when a dice is rolled __100__ times, chances to get ‘1’ are ``15-18%`` and if we roll the dice __1000__ times, the chances to get ‘1’ is, again, the same, which averages to ``16.7% (1/6)``. If we roll two dices simultaneously, there are __36__ possible combinations. The probability of rolling ‘1’ (with six possible combinations) again averages to around ``16.7%``, i.e., ``(6/36)``. More the number of dices more elaborate will be the normal distribution graph.

# %% [markdown]
# ![rolling%20of%20dice%20example%20pic.jpg](attachment:rolling%20of%20dice%20example%20pic.jpg)

# %% [markdown]
# ### Q5. In the short term, how can you expect a probability distribution to behave? What do you think will happen as the number of trials grows?

# %% [markdown]
# ##### ANSWER:

# %% [markdown]
# As the number of trials grows Variance will _decrease_ .

# %% [markdown]
# ### Q6. What kind of object can be shuffled by using random.shuffle?

# %% [markdown]
# ##### ANSWER:

# %% [markdown]
# The kind of object can be shuffled by using ``random.shuffle`` are :
#
#
# - lists (``list``)
#
#
# - strings (``str``)
#
#
# - tuples (``tuple``)

# %% [markdown]
# ### Q7. Describe the math package's general categories of functions.

# %% [markdown]
# ##### ANSWER:

# %% [markdown]
# The Math package's general categories of functions are:
#
# - Trigonometric functions
#
#
# - Quadratic functions
#
#
# - Exponential functions
#
#
# - Hyperbolic functions
#
#
# - Periodic functions
#
#
# - Arithmetic functions
#
#
# - Logarithimic functions
#
#
# - Conversions to Integer

# %% [markdown]
# ### Q8. What is the relationship between exponentiation and logarithms?

# %% [markdown]
# ##### ANSWER:

# %% [markdown]
# __Exponentiation__ and __logarithms__ are inverse of each other.

# %% [markdown]
# ### Q9. What are the three logarithmic functions that Python supports?

# %% [markdown]
# ##### ANSWER:

# %% [markdown]
# The Three __Logarithmic Functions__ that Python supports are:
#
#
# - ``log2(x)`` - logarithmic value of x to base 2
#
#
# - ``log10(x)`` - logarithmic value of x to base 10
#
#
# - ``log1p(a)`` - This function is used to compute logarithm(1+a)
